# %%
# %matplotlib inline
from Utils.setupDataset import get_dataset
from Utils.plot_results import plot_featureDistribution, get_plotableFeatures, plot_topRanked

m_set = get_dataset("Datasets/M_DEV_dataset.pickle")
w_set = get_dataset("Datasets/W_DEV_dataset.pickle")
wo_set = get_dataset("Datasets/WO_DEV_dataset.pickle")
m_ranks = "Datasets/M_SELECTIONS_univariate.csv"
w_ranks = "Datasets/W_SELECTIONS_univariate.csv"
wo_ranks = "Datasets/WO_SELECTIONS_univariate.csv"

# %% [markdown]
# # Univariate Feature Selections - Top Rankings

# %%
plot_topRanked(m_ranks, 10, "Martin Dataset")
plot_topRanked(w_ranks, 15, "Wiki Dataset")
plot_topRanked(wo_ranks, 15, "wiki wo Dataset")

# %% [markdown]
# # Feature Distribution Plots
# Histograms *(currently only implemented for integer type features)*

# %% [markdown]
# ## Martin Dataset

# %%
for f in get_plotableFeatures():
    plot_featureDistribution(m_set, f)

# %% [markdown]
# ## Wiki Dataset

# %%
for f in get_plotableFeatures():
    plot_featureDistribution(w_set, f)

# %%
for f in get_plotableFeatures():
    plot_featureDistribution(wo_set, f)
