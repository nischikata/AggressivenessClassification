# %%
from Utils.plot_results import plot_uni_VS_RFE as scatter
from Utils.plot_results import plot_ftest_VS_RFE as f
from Utils.plot_results import plot_ranksum_VS_RFE as rank
from Utils.plot_results import plot_mi_VS_RFE as mi
from Utils.plot_results import plot_f_VS_mi as splatter

# %%
scatter("Datasets/W_SELECTIONS_univariate.csv", "Datasets/W_SELECTIONS_RFE.csv", n=15)
f("Datasets/W_SELECTIONS_univariate.csv", "Datasets/W_SELECTIONS_RFE.csv", n=15)
rank("Datasets/W_SELECTIONS_univariate.csv", "Datasets/W_SELECTIONS_RFE.csv", n=15)
mi("Datasets/W_SELECTIONS_univariate.csv", "Datasets/W_SELECTIONS_RFE.csv", n=15)
# Out:
# 54
# 43
# 54
# 62

# %%
scatter("Datasets/W_SELECTIONS_univariate.csv", "Datasets/W_SELECTIONS_RFE.csv", n=20)
# Out:
# 62

# %%
scatter("Datasets/M_SELECTIONS_univariate.csv", "Datasets/M_SELECTIONS_RFE.csv", n=20)
f("Datasets/M_SELECTIONS_univariate.csv", "Datasets/M_SELECTIONS_RFE.csv", n=20)
rank("Datasets/M_SELECTIONS_univariate.csv", "Datasets/M_SELECTIONS_RFE.csv", n=20)
mi("Datasets/M_SELECTIONS_univariate.csv", "Datasets/M_SELECTIONS_RFE.csv", n=20)
# Out:
# 60
# 60
# 60
# 60
